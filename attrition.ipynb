# %%
print("hello")
# Out:
# hello

# %%
# !pip install pandas numpy matplotlib seaborn scikit-learn
# Out:
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ------- -------------------------------- 1.8/9.9 MB 9.1 MB/s eta 0:00:01
#    ------------- -------------------------- 3.4/9.9 MB 8.5 MB/s eta 0:00:01
#    ---------------------- ----------------- 5.5/9.9 MB 9.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.3/9.9 MB 8.7 MB/s eta 0:00:01
#    -------------------------------------- - 9.4/9.9 MB 9.0 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 8.9 MB/s  0:00:01
# ...
#    ---------------------------------------- 0.0/12.5 MB ? eta -:--:--
#    ----- ---------------------------------- 1.8/12.5 MB 9.2 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.7/12.5 MB 9.0 MB/s eta 0:00:01
#    ------------------ --------------------- 5.8/12.5 MB 9.5 MB/s eta 0:00:01
#    -------------------------- ------------- 8.1/12.5 MB 9.9 MB/s eta 0:00:01
# ...

# %%
import os 
os.listdir()
# Out:
# ['.dist',
#  '.git',
#  '.gitignore',
#  'attrition.csv.csv',
#  'attrition.ipynb',
#  'README.md']

# %%
import pandas as pd
df=pd.read_csv("attrition.csv")
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...
